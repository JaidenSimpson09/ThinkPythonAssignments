# %% [markdown]
# <a href="https://colab.research.google.com/github/JaidenSimpson09/ThinkPythonAssignments/blob/main/Week14/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

#CLASS DEFINITIONS
#Book class
class Book:

#__init__
  def __init__(self, title, author):
  #Accept title and author as parameters
  #Create title attribute
    self.title = title
  #Create author attribute
    self.author =  author
  #Create is_available attribute defaulting to true
    self.is_available = True

#__str__
  def __str__(self):
  #If book is available, status is "Available"
    if self.is_available == True:
      status = "Available"
  #Otherwise status is "Checked out"
    else:
      status = "Checked Out"
  #Return formatted string with title, author, and status
    return f"{self.title} by { self.author} - {status}"

  #Checkout
  def checkout(self):
    #Set is_available to false
    self.is_available = False

  #Return book
  def return_book(self):
    #Set is_available to true
    self.is_available = True


#PROGRAM LOGIC
#Create at least 2 seperate book objects
Book1 = Book("Think Python", "Allen Downey")
Book2 = Book("The Hobbit", "J.R.R. Tolkien")
#Print the status of both books
print("Library Status")
print(Book1)
print(Book2)
#Check out one of the books using checkout()
print()
print("checking out 'The Hobbit'")
Book2.checkout()
#Print both books again to show updated status
print()
print("Updated Status")
print(Book1)
print(Book2)
# Out:
# Library Status
# Think Python by Allen Downey - Available
# The Hobbit by J.R.R. Tolkien - Available
#
# checking out 'The Hobbit'
#
# Updated Status
# Think Python by Allen Downey - Available
# The Hobbit by J.R.R. Tolkien - Checked Out
