# %% [markdown]
# <a href="https://colab.research.google.com/github/JaidenSimpson09/ThinkPythonAssignments/blob/main/journal/journal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATEMENTS

#FUNCTION DEFINITIONS

#write_entry
  # Accept filename and entry as parameters
  # Open file in append mode ('a')
  # Write entry to file
  # Make sure each entry goes on a new line using \n
  # Close the file

#read_juronal
  # Accept filename as a parameter
  # Open file in read mode ('r')
  # Read all contents
  # Print contents to screen

#PROGRAM LOGIC
# Ask user if they want to write, read or quit
# If W, get entry and call write_entry
# If R, call read_juronal
# Repeat using a loop untill the user types "quit"
