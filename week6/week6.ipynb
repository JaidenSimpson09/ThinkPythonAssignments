# %% [markdown]
# <a href="https://colab.research.google.com/github/JaidenSimpson09/ThinkPythonAssignments/blob/main/week6/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math
import math


# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
def area (radius):
    return math.pi * radius * radius

# 2. Define circumference(radius): returns 2 * pi * r
def circumference (radius):
    return 2 * math.pi * radius


# 3. Define volume(radius, height):
#    - Call area(radius) and multiply by height.
#    - Return the result.
def volume(radius, height):
    base_area = area(radius)
    return base_area * height

# PROGRAM LOGIC
# 1. Input for radius (float)
radius = float(input("enter radius: "))


# 2. Call and print area and circumference.
print ("Area: ", area(radius))
print("Circumference:", circumference(radius))

# 3. Input for height (float)
height = float(input("Enter Height: "))

# 4. Call and print volume.
print("Cylinder Volume: ", volume( radius, height))
# Out:
# enter radius: 1
# Area:  3.141592653589793
# Circumference: 6.283185307179586
# Enter Height: 8
# Cylinder Volume:  25.132741228718345
