# %% [markdown]
# <a href="https://colab.research.google.com/github/JaidenSimpson09/ThinkPythonAssignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
def Print_bio(name, age, goal):
  print("*" * 25)
  print("name:", name, "age:", age, "goal:", goal)
  print("*" * 25)

# PROGRAM LOGIC
Print_bio ("Jaiden", 16, "learn piano")
Print_bio ("Nate Feuerstein", 34, "Make music about his life")
Print_bio ("Barry allen (the flash)", 25, "save the world")
# Out:
# *************************
# name: Jaiden age: 16 goal: learn piano
# *************************
# *************************
# name: Nate Feuerstein age: 34 goal: Make music about his life
# *************************
# *************************
# name: Barry allen (the flash) age: 25 goal: save the world
# *************************
