# %% [markdown]
# <a href="https://colab.research.google.com/github/JaidenSimpson09/ThinkPythonAssignments/blob/main/Week7/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FUNCTION DEFINITIONS

# 1. Define verify_pin():
def verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
  while true:
#    - Return True
    pin = input ("enter pin: ")

    if pin =="1234":
      print ("pin verfied.")
      return True

    else:
      print ("incorrect pin. try again")

  verify_pin()

# 2. Define withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new (or old) balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
# 2. Call verify_pin()
# 3. Get withdrawal amount from user input
# 4. Update current_balance by calling withdraw()
# 5. Print the final balance
