# %% [markdown]
# <a href="https://colab.research.google.com/github/JaidenSimpson09/ThinkPythonAssignments/blob/main/roster/roster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATMENTS

#FUNCTION DEFINITIONS
  #add_players
    #get names from user
    #stop when user types "quit"
    #add names to list

  Def add_players(roster):
    while true:
      name = input("enter player name(or 'quit' to stop): ")

      if name.lower()== "quit":
        break

      roster.append(name)



  #is_on_roster
    #check if name is on the list
    #return true or false

#PROGRAM LOGIC
  #make empty list
roster = []
  #call add players
add_players(roster)
  #ask for name to search
  #call is_on_roster
  #print result
print(roster)
